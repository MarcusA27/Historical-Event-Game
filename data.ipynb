# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/marcusarocha/Downloads/World Important Dates.csv')

# %%
df.head()
# Out:
#    Sl. No                      Name of Incident     Date    Month     Year  \
# 0       1  Indus Valley Civilization Flourishes  Unknown  Unknown  2600 BC
# 1       2               Battle of the Ten Kings  Unknown  Unknown  1400 BC
# 2       6  Establishment of the Delhi Sultanate  Unknown  Unknown     1206
# 3       7                     Battle of Panipat       21    April     1526
# 4       8          Establishment of British Raj        1      May     1858
#
#   Country Type of Event    Place Name  \
# 0   India  Civilization  Indus Valley
# 1   India        Battle        Punjab
# 2   India     Political         Delhi
# 3   India        Battle       Panipat
# 4   India      Colonial   Whole India
#
#                                               Impact  \
# 0  Development of one of the world's earliest urb...
# 1  Rigvedic tribes consolidated their control ove...
# 2          Muslim rule established in parts of India
# 3           Foundation of the Mughal Empire in India
# ...

# %%
df = df.drop(["Outcome", "Important Person/Group Responsible", "Affected Population", "Place Name"], axis=1)
df_filtered = df[df["Date"] != "Unknown"]

# %%
df_filtered.head()
# Out:
#    Sl. No                  Name of Incident Date     Month  Year Country  \
# 3       7                 Battle of Panipat   21     April  1526   India
# 4       8      Establishment of British Raj    1       May  1858   India
# 5       9                Partition of India   15    August  1947   India
# 6      10  IndoUnknownPakistani War of 1971    3  December  1971   India
# 7      11    PokhranUnknownII Nuclear Tests   11       May  1998   India
#
#   Type of Event                                             Impact
# 3        Battle           Foundation of the Mughal Empire in India
# 4      Colonial        Start of direct British governance in India
# 5     Partition  Creation of India and Pakistan; massive popula...
# 6           War              Led to the independence of Bangladesh
# 7  Nuclear Test              India declared itself a nuclear state

# %%
random_row = df_filtered.sample(n=1)
random_row
# Out:
#      Sl. No           Name of Incident Date  Month  Year       Country  \
# 942     998  Independence from Britain   27  April  1961  Sierra Leone
#
#     Type of Event                                         Impact
# 942  Independence  Transition to sovereignty after British rule.
